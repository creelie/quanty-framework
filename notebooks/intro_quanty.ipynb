# %%
# QuanTY: Geometric–Topological Quantum Computation

# %%
import numpy as np
from quanty.algorithms.geometric_qho import GeometricQuantumHarmonicOscillator

# %%
algo = GeometricQuantumHarmonicOscillator()
x0 = np.array([1.0, 0.0])
algo.run(x0, steps=100)
# Out:
# np.float64(0.5679880217110845)

# %%
git add notebooks/intro_quanty.ipynb
git commit -m "Add introductory Jupyter notebook for QuanTY"
git push
# Out:
#   Cell In[7], line 1
#     git add notebooks/intro_quanty.ipynb
#         ^
# SyntaxError: invalid syntax
